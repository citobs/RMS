# %% [markdown]
# # 영화추천시스템 (RMS)

# %% [markdown]
# 1. Demographic Filtering(인구통계학적 필터링)
# 2. Content Based Filtering(콘텐츠 기반 필터링)
# 3. Collaborative Filtering(협업필터링)

# %% [markdown]
# ## 1. 인구통계학적 필터링(DF)

# %%
import pandas as pd
import numpy as np
from IPython.display import Image

df1 = pd.read_csv('../dataset/tmdb_5000_credits.csv')
df2 = pd.read_csv('../dataset/tmdb_5000_movies.csv')

# %%
df1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df2.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %% [markdown]
# ### 데이터 합치기(df1과 df2)

# %%
# 데이터 사전파악
df1.shape, df2.shape
# Out:
# ((4803, 4), (4803, 20))

# %%
df1['title'].equals(df2['title']), df1['title'].equals(df2['status'])
# Out:
# (True, False)

# %%
#id를 기준으로 concat
df1.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
#df1의 moive_id를 id로 변경한다.
df1.columns =['id','title','cast', 'crew' ]
df1
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# ...

# %%
#df2 데이터 전처리
df1[['id','cast','crew']]
# Out:
#           id                                               cast  \
# 0      19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1        285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3      49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4      49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...      ...                                                ...
# 4798    9367  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799   72766  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  231617  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  126186  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802   25975  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# ...

# %%
#merge(id를 기준으로 on!)
df2 = df2.merge(df1[['id','cast','crew']],on='id')

# %%
df2
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
#imag file 삽입코드
#from IPython.display import Image
#코드블럭 Image('경로명')
#마크업은 ![nn](파일경로)
#|Image('./img/20230106_120533.png')

# %% [markdown]
# 1. 영화1 : 영화의 평점이 10/10 -> 5명이 평가
# 2. 영화2 : 영화의 평점이 8/10 -> 10명이 평가
# 3. 가중치설정법
# - ![nn](img/20230106_120533.png)
# - V is the number of votes for the moive;
# - m is minimum votes required to be listed in the chart;
# - R is the average rating of the movie; And
# - C is the mean vote across the whole report

# %%
C = df2['vote_average'].mean()
C
# Out:
# 6.092171559442011

# %%
m = df2['vote_count'].quantile(0.9)
m
# Out:
# 1838.4000000000015

# %%
q_movies = df2.copy().loc[df2['vote_count']>=m]
q_movies.shape
# Out:
# (481, 22)

# %%
q_movies['vote_count'].sort_values()
# Out:
# 2585     1840
# 195      1851
# 2454     1859
# 597      1862
# 1405     1864
#         ...
# 788     10995
# 16      11776
# 0       11800
# 65      12002
# 96      13752
# Name: vote_count, Length: 481, dtype: int64

# %%
def weighted_rating(x,m=m,C=C):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m)*R) + (m/(m+v)*C)

# %%
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)
q_movies.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
q_movies = q_movies.sort_values('score',ascending=False)
q_movies[['title', 'vote_count','vote_average','score']].head(10)
# Out:
#                                               title  vote_count  vote_average  \
# 1881                       The Shawshank Redemption        8205           8.5
# 662                                      Fight Club        9413           8.3
# 65                                  The Dark Knight       12002           8.2
# 3232                                   Pulp Fiction        8428           8.3
# 96                                        Inception       13752           8.1
# 3337                                  The Godfather        5893           8.4
# 95                                     Interstellar       10867           8.1
# 809                                    Forrest Gump        7927           8.2
# 329   The Lord of the Rings: The Return of the King        8064           8.1
# 1990                        The Empire Strikes Back        5879           8.2
#
#          score
# 1881  8.059258
# 662   7.939256
# 65    7.920020
# 3232  7.904645
# 96    7.863239
# ...

# %%
pop = df2.sort_values('popularity',ascending=False)
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.barh(pop['title'].head(6),pop['popularity'].head(6),align='center',color='skyblue')
plt.gca().invert_yaxis()
plt.xlabel("Popularity")
plt.title('Popularity Movies')
# Out:
# Text(0.5, 1.0, 'Popularity Movies')

# %% [markdown]
# ### Content Based Filtering(컨텐츠 기반 필터링)

# %%
df2['overview'].head(5)
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %% [markdown]
# ### Bag Of Words - BOW(텍스트분석의 기초)

# %% [markdown]
# i am a Boy
# i am a girl
# i(2) am(2) a(2) boy(1)
#
# 1. TfidVectorizer(TF-IDF 기반의 벡터화)
# 2. CounterVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#영어에서 의미없는 단어들 제외(the, a 등)
tfidf = TfidfVectorizer(stop_words='english')

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
ENGLISH_STOP_WORDS
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
# ...

# %%
#overview에 빈값이 있는가? 그렇다면 채워라 ! fillna
if df2['overview'].isnull().values.any() == True:
    df2['overview'] = df2['overview'].fillna('')
else:
    df2['overview'].isnull().values.any()
    
# 찍어보기
df2['overview'].isnull().values.any()
# Out:
# False

# %%
tfidf_matrix = tfidf.fit_transform(df2['overview'])
tfidf_matrix.shape

#단어개수 보기
tfidf_matrix
# Out:
# <4803x20978 sparse matrix of type '<class 'numpy.float64'>'
# 	with 125840 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics.pairwise import linear_kernel

#cosine 유사도(x,y값)
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim.shape
# Out:
# (4803, 4803)

# %%
#영화제목을 이용해서 인덱스를 알아오자
indices = pd.Series(df2.index, index=df2['title']).drop_duplicates()
indices
# Out:
# title
# Avatar                                         0
# Pirates of the Caribbean: At World's End       1
# Spectre                                        2
# The Dark Knight Rises                          3
# John Carter                                    4
#                                             ...
# El Mariachi                                 4798
# Newlyweds                                   4799
# Signed, Sealed, Delivered                   4800
# Shanghai Calling                            4801
# My Date with Drew                           4802
# Length: 4803, dtype: int64

# %%
#영화 Spectre의 인덱스번호 찾아오기
indices['Spectre']
#인덱싱을 이용한 영화정보 얻어오기
df2.iloc[[2]]
# Out:
#       budget                                             genres  \
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                       homepage      id  \
# 2  http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#   original_title                                           overview  \
# 2        Spectre  A cryptic message from Bond’s past sends him o...
#
#    popularity                               production_companies  ...  \
# 2  107.376788  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
#
#      revenue runtime                                   spoken_languages  \
# 2  880674609   148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
#
#      status                tagline    title vote_average vote_count  \
# 2  Released  A Plan No One Escapes  Spectre          6.3       4466
#
# ...

# %%
#영화함수(영화의 제목을 입력받으면 코사인 유사도를 통해서 가장 유사도 높은 상위 10개의 영화목록을 반환)
def get_recom(title, cosine_sim=cosine_sim):
    #영화 제목을 통해서 전체데이터 기준 그 영화의 index 값얻기
    idx = indices[title]
    #코사인 유사도 매트릭스에서 idx에 해당하는 데이터를(idx(영화인덱스), 유사도) 형태로 얻기
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    #코사인 유사도 기준으로내림차순 정렬
    sim_scores = sorted(sim_scores,key=lambda x:x[1], reverse=True)
    
    #자기 자신을 제외한 10개의 추천 영화를 슬라이싱
    sim_scores = sim_scores[1:11]
    
    #추천 영화 목록 10개의 인덱스 정보 추출
    test_moive_indices = [i[0] for i in sim_scores]
    
    #인덱스 정보를 통해 영화 제목추출
    return df2['title'].iloc[test_moive_indices]

# %%
test_idx = indices['Spectre'] # 영화 제목을 통해서 데이터기준 그 영화의 인덱스 값 얻기
test_idx
# Out:
# 2

# %%
cosine_sim[2]
# Out:
# array([0.        , 0.        , 1.        , ..., 0.01488159, 0.        ,
#        0.        ])

# %%
#코사인아도 매트릭스에서 idx에 해당하는 데이터를(idx(영화인덱스), 유사도) 형태로 얻기
test_sim_scores = list(enumerate(cosine_sim[2]))

# %%
#코사인 유사도 기준으로내림차순 정렬
test_sim_scores = sorted(test_sim_scores,key=lambda x:x[1], reverse=True)
test_sim_scores[1:11] # 자기 자신을 제외한 10개의 추천영화를 슬라이싱
# Out:
# [(1343, 0.25696279479227285),
#  (4071, 0.19885857934937373),
#  (3162, 0.18926775765001047),
#  (1717, 0.16820209604563147),
#  (11, 0.16509044146404833),
#  (4339, 0.1440273127061933),
#  (29, 0.1341121725535458),
#  (1880, 0.13274747112697027),
#  (3336, 0.12907010344302589),
#  (1743, 0.11916372358449356)]

# %%
def get_second(x):
    return x[1]

lst = ['인덱스', '유사도']
print(get_second(lst))

#이걸 람다식으로 변경하면
(lambda x: x[1])(lst)
# Out:
# 유사도
# '유사도'

# %%
#추천 영화 목록 10개의 인덱스 정보 추출
test_moive_indices = [i[0] for i in test_sim_scores[1:11]]
test_moive_indices
# Out:
# [1343, 4071, 3162, 1717, 11, 4339, 29, 1880, 3336, 1743]

# %%
#인덱스 정보를 통해 영화 제목추출
df2['title'].iloc[test_moive_indices]
# Out:
# 1343    Never Say Never Again
# 4071    From Russia with Love
# 3162              Thunderball
# 1717               Safe Haven
# 11          Quantum of Solace
# 4339                   Dr. No
# 29                    Skyfall
# 1880              Dance Flick
# 3336     Diamonds Are Forever
# 1743                Octopussy
# Name: title, dtype: object

# %%
#영화제목보자
df2['title'][:20]
# Out:
# 0                                          Avatar
# 1        Pirates of the Caribbean: At World's End
# 2                                         Spectre
# 3                           The Dark Knight Rises
# 4                                     John Carter
# 5                                    Spider-Man 3
# 6                                         Tangled
# 7                         Avengers: Age of Ultron
# 8          Harry Potter and the Half-Blood Prince
# 9              Batman v Superman: Dawn of Justice
# 10                               Superman Returns
# 11                              Quantum of Solace
# 12     Pirates of the Caribbean: Dead Man's Chest
# 13                                The Lone Ranger
# 14                                   Man of Steel
# 15       The Chronicles of Narnia: Prince Caspian
# 16                                   The Avengers
# 17    Pirates of the Caribbean: On Stranger Tides
# 18                                 Men in Black 3
# ...

# %%
get_recom('Avengers: Age of Ultron')
# Out:
# 16                    The Avengers
# 79                      Iron Man 2
# 68                        Iron Man
# 26      Captain America: Civil War
# 227                 Knight and Day
# 31                      Iron Man 3
# 1868            Cradle 2 the Grave
# 344                    Unstoppable
# 1922                    Gettysburg
# 531        The Man from U.N.C.L.E.
# Name: title, dtype: object

# %%
get_recom('The Avengers')
# Out:
# 7               Avengers: Age of Ultron
# 3144                            Plastic
# 1715                            Timecop
# 4124                 This Thing of Ours
# 3311              Thank You for Smoking
# 3033                      The Corruptor
# 588     Wall Street: Money Never Sleeps
# 2136         Team America: World Police
# 1468                       The Fountain
# 1286                        Snowpiercer
# Name: title, dtype: object

# %% [markdown]
# ### Ending(머신러닝 기초로 만든 추천시스템 끝!)
